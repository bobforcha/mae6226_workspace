# %% [markdown]
# # Joukowski Transformation

# %% [markdown]
# ## 1. Complex Numbers in Python
#
# 2 complex planes: $z = x + jy$ and $\xi = \xi_x + j\xi_y$
#
# Joukowski Transformation:
#
# $$\xi = z + \frac{c^2}{z}$$

# %%
# run notebook containing imports and class definitions
# %run ./resources.ipynb

# %%
3 + 2j
# Out:
# (3+2j)

# %%
a = 3
b = 3
z = a + b*1j
print('z = ', z)
print('The type of the variable is', type(z))
# Out:
# z =  (3+3j)
# The type of the variable is <class 'complex'>

# %% [markdown]
# ### Exercises

# %%
a = 2.75 + 3.69*1j
b = 8.55 - 6.13*1j
a*b
# Out:
# (46.1322+14.692000000000004j)

# %%
1.4 * np.exp(0.0 + 5.32*1J)
# Out:
# (0.79927078585823497-1.1494199453957457j)

# %%
(7.51 - 9.15*1j)/(4.43 + 9.64*1j)
# Out:
# (-0.4880897698448308-1.0033441577191493j)

# %% [markdown]
# ## 2. Shapes Created by the Joukowski Transformation

# %%
N = 100
x_start, x_end = -3.0, 3.0
y_start, y_end = -3.0, 3.0
c = 1.0

# %% [markdown]
# ### $R = 1.0$

# %%
# create circle
R = 1.0
theta = np.linspace(0.0, 2*math.pi, N)
x_circ = R*np.cos(theta)
y_circ = R*np.sin(theta)
z_circ = x_circ + y_circ*1j

# transform
xi_circ = z_circ + c**2/z_circ

# %%
# plots
size = 6.5
plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.plot(z_circ.real, z_circ.imag, color='#CD2305', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title('$z$-plane', fontsize=20)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.grid(True)

plt.subplot(122)
plt.plot(xi_circ.real, xi_circ.imag, color='#CD2305', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.grid(True);

# %% [markdown]
# ### $R = 1.5$

# %%
R2 = 1.5
z_circ2 = R2*np.cos(theta) + R2*np.sin(theta)*1j

# transform
xi_circ2 = z_circ2 + 1/z_circ2

#plots
plt.figure(figsize=(size, size))
plt.xlabel('x', fontsize=16)
plt.ylabel('iy', fontsize=16)
plt.title(r'$z$-plane', fontsize=20)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.grid(True)
plt.plot(z_circ2.real, z_circ2.imag, color='#CD2305', linewidth=2, linestyle='-');

# %%
plt.figure(figsize=(size, size))
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.grid(True)
plt.plot(xi_circ2.real, xi_circ2.imag, color='#CD2305', linewidth=2, linestyle='-');

# %% [markdown]
# ### $R = 1.2, \quad x_c = c -R$

# %%
R3 = 1.2
c = 1.0
x_c = c-R3
y_c = 0.0

z_circ3 = (R3*np.cos(theta) + x_c) + (R3*np.sin(theta) + y_c)*1j

# transform
xi_circ3 = z_circ3 + c/z_circ3

# plots
plt.figure(figsize=(size, size))
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.grid(True)
plt.plot(xi_circ3.real, xi_circ3.imag, color='#CD2305', linewidth=2, linestyle='-');

# %% [markdown]
# ### $R = \sqrt{\left(c - x_c\right)^2 + y_c^2}\text{,}\quad \left(x_c,y_c\right) = \left(-0.1,0.1\right)$

# %%
x_c, y_c = -0.1, 0.1
R4 = np.sqrt((c - x_c)**2 + y_c**2)

z_circ4 = (R4*np.cos(theta) + x_c) + (R4*np.sin(theta) + y_c)*1j

# transform
xi_circ4 = z_circ4 + c/z_circ4

# plots
plt.figure(figsize=(size, size))
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.grid(True)
plt.plot(xi_circ4.real, xi_circ4.imag, color='#CD2305', linewidth=2, linestyle='-');

# %% [markdown]
# For question 4, $\theta = 0$ corresponds to the trailing edge

# %% [markdown]
# ## 3. Grid Points on the $z$ - plane Using Polar Coordinates

# %%
# build a grid in polar coordinates
N_r = 100
N_theta = 145
R = 1.15
r_end = 5
r = np.linspace(R, r_end, N_r)
theta = np.linspace(0, 2*math.pi, N_theta)

Rho, Theta = np.meshgrid(r, theta)

x_c = c - R
y_c = 0.0

Z = (Rho*np.cos(Theta) + x_c) + (Rho*np.sin(Theta) + y_c)*1j

# transform
Xi = Z + c**2/Z

# plots
size = 6.5
plt.figure(figsize=(2*size + 1, size))
plt.subplot(121)
plt.scatter(Z.real, Z.imag, color='#CD2305', s=10, marker='o')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title('$z$-plane', fontsize=20)
plt.xlim(-6.0, 6.0)
plt.ylim(-6.0, 6.0)
plt.grid(True)

plt.subplot(122)
plt.scatter(Xi.real, Xi.imag, color='#CD2305', s=10, marker='o')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)
plt.xlim(-6.0, 6.0)
plt.ylim(-6.0, 6.0)
plt.grid(True)

# %% [markdown]
# ## 4. Flow over a symmetric Joukowski airfoil with zero angle of attack

# %% [markdown]
# ### Stream function and streamlines
#
# $$\psi\left(\xi\right) = \psi\left(\xi\left(z\right)\right)$$

# %%
# freestream velocity and doublet radius
u_inf = 1.0
kappa = 2*math.pi*u_inf*R**2
dub = Doublet(kappa, x_c, y_c)

# calculate stream function
psi_dub = dub.stream_function(Z.real, Z.imag)
psi = psi_dub + u_inf*Z.imag

# plots
contlev = np.linspace(np.min(psi).real, np.max(psi).real, 51)
circ_z = (R*np.cos(theta) + x_c) + (R*np.sin(theta) + y_c)*1j
circ_xi = circ_z + c**2/circ_z

plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.contour(Z.real, Z.imag, psi, levels=contlev)
plt.plot(circ_z.real, circ_z.imag, color="#FF0D0D", linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
plt.contour(Xi.real, Xi.imag, psi, levels=contlev)
plt.plot(circ_xi.real, circ_xi.imag, color='#FF0D0D', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20);

# %% [markdown]
# ### Velocity Vectors and Pressure Coefficients
#
# $$W_\xi = \frac{u_z - iv_z}{1 - \left(\frac{c}{z}\right)^2}$$

# %%
# calculate velocity fields
u_dub, v_dub = dub.velocity(Z.real,Z.imag)
u_fs = u_inf*np.ones(np.shape(Z.real))
v_fs = np.zeros(np.shape(Z.imag))
u = u_dub + u_fs
v = v_dub + v_fs
w_z = u - v*1j

w_xi = w_z/(1 - (c/Z)**2)

# plots
plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.quiver(Z.real[::2,::2], Z.imag[::2,::2], w_z.real[::2,::2], -w_z.imag[::2,::2], units='inches', width=0.01, scale_units='inches', scale=8.0)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
plt.quiver(Xi.real[::2,::2], Xi.imag[::2,::2], w_xi.real[::2,::2], -w_xi.imag[::2,::2], units='inches', width=0.01, scale_units='inches', scale=8.0)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title(r'$\xi$-plane', fontsize=20);
# Out:
# /home/bob/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:9: RuntimeWarning: invalid value encountered in true_divide

# %%
# calculate pressure coefficients
c_p_z = 1.0 - (w_z.real**2 + w_z.imag**2)/u_inf**2

c_p_xi = 1.0 - (w_xi.real**2 + w_xi.imag**2)/u_inf**2

# plots
plt.figure(figsize=(2*size+3, size))
plt.subplot(121)
contf = plt.contourf(Z.real, Z.imag, c_p_z, levels=np.linspace(-1.0, 1.0, 51), extend='both', cmap=plt.cm.jet)
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
contf2 = plt.contourf(Xi.real, Xi.imag, c_p_xi, levels=np.linspace(-1.0, 1.0, 51), extend='both', cmap=plt.cm.jet)
cbar2 = plt.colorbar(contf2)
cbar2.set_label('$C_p$', fontsize=16)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title(r'$\xi$-plane', fontsize=20);

# %% [markdown]
# ### Questions
#
# What is the strength of the doublet?

# %%
print('kappa = ', kappa)
# Out:
# kappa =  8.309512568745001

# %% [markdown]
# What is the velocity at the $62^{nd}$ point on the airfoil surface?

# %%
w_xi[61][0]
# Out:
# (1.1063384662852436-0.52363334929849692j)

# %% [markdown]
# What is the minimum value of the pressure coefficient on the airfoil surface?

# %%
np.min(c_p_xi[1:])
# Out:
# -0.68775567409240423

# %% [markdown]
# ## 5. Flow over a symmetric Joukowski airfoil with non-zero angle of attack, without circulation

# %%
# add in angle of attack
a_o_a = 20*math.pi/180
Z_prime = (Z - (x_c + y_c*1j))*np.exp(-1j*a_o_a)
dub2 = Doublet(kappa, 0.0, 0.0)
u_prime_dub, v_prime_dub = dub2.velocity(Z_prime.real, Z_prime.imag)
u_prime = u_prime_dub + u_fs
v_prime = v_prime_dub

w_z_prime = u_prime - v_prime*1j
w_z = w_z_prime*np.exp(-1j*a_o_a)
w_xi = w_z/(1 - (c/Z)**2) 

psi_prime_fs = u_inf*Z_prime.imag
psi_prime = psi_prime_fs + dub2.stream_function(Z_prime.real, Z_prime.imag)

psi = psi_prime*np.exp(-1j*a_o_a)

c_p_z = 1.0 - (np.abs(w_z)/u_inf)**2

c_p_xi = 1.0 - (np.abs(w_xi)/u_inf)**2

# plots
contlev = np.linspace(np.min(psi).real, np.max(psi).real, 51)

plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.contour(Z.real, Z.imag, psi, levels=contlev)
plt.plot(circ_z.real, circ_z.imag, color='#FF0D0D', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
plt.contour(Xi.real, Xi.imag, psi, levels=contlev)
plt.plot(circ_xi.real, circ_xi.imag, color='#FF0D0D', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)

plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.quiver(Z.real[::3,::3], Z.imag[::3,::3], w_z.real[::3,::3], -w_z.imag[::3,::3], units='inches', width=0.01, scale_units='inches', scale=7.0)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
plt.quiver(Xi.real[::3,::3], Xi.imag[::3,::3], w_xi.real[::3,::3], -w_xi.imag[::3,::3], units='inches', width=0.01, scale_units='inches', scale=7.0)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title(r'$\xi$-plane', fontsize=20)

plt.figure(figsize=(2*size+3, size))
plt.subplot(121)
contf = plt.contourf(Z.real, Z.imag, c_p_z, levels=np.linspace(-1.0, 1.0, 51), extend='both', cmap=plt.cm.jet)
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
contf2 = plt.contourf(Xi.real, Xi.imag, c_p_xi, levels=np.linspace(-1.0, 1.0, 51), extend='both', cmap=plt.cm.jet)
cbar2 = plt.colorbar(contf2)
cbar2.set_label('$C_p$', fontsize=16)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title(r'$\xi$-plane', fontsize=20);
# Out:
# /home/bob/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: RuntimeWarning: divide by zero encountered in true_divide
# /home/bob/anaconda3/lib/python3.6/site-packages/numpy/ma/core.py:2761: ComplexWarning: Casting complex values to real discards the imaginary part
#   order=order, subok=True, ndmin=ndmin)

# %% [markdown]
# ### Questions:
#
# Do you think the flow over the airfoil is reasonable?
#
# No, because of the trailing edge velocities, and apparent lack of lift or drag.
#
# Where are the stagnation points on the airfoil?

# %%
np.unravel_index(np.argmax(c_p_xi[:,0]), np.shape(c_p_xi[:,0]))[0]
# Out:
# 8

# %%
np.unravel_index(np.argmax(c_p_xi[20:,0]), np.shape(c_p_xi[20:,0]))[0] + 20
# Out:
# 80

# %% [markdown]
# How much is the lift?
#
# $0$

# %% [markdown]
# How much is the drag?
#
# $0$

# %% [markdown]
# What is the velocity at the 50th point on the airfoil surface?

# %%
w_xi[49,0]
# Out:
# (1.4830654150147842-0.092075495007288205j)

# %% [markdown]
# What is the pressure coefficient at the 75th point on the airfoil?

# %%
c_p_xi[74,0]
# Out:
# -0.48520991643725986

# %% [markdown]
# ## Flow over a symmetric Joukowski airfoil with non-zero angle of attack, with circulation

# %%
# add vortex
gamma = 4*math.pi*u_inf*R*np.sin(a_o_a)
vort = Vortex(gamma, x_c, y_c)

psi_vort = vort.stream_function(Z.real, Z.imag)
psi += psi_vort

u_vort, v_vort = vort.velocity(Z.real, Z.imag)

w_z += (u_vort - v_vort*1j)

w_xi = w_z/(1 - (c/Z)**2)

c_p_z = 1.0 - (np.abs(w_z)/u_inf)**2

c_p_xi = 1.0 - (np.abs(w_xi)/u_inf)**2

# plots
contlev = np.linspace(np.min(psi).real, np.max(psi).real, 51)

plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.contour(Z.real, Z.imag, psi, levels=contlev)
plt.plot(circ_z.real, circ_z.imag, color='#FF0D0D', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
plt.contour(Xi.real, Xi.imag, psi, levels=contlev)
plt.plot(circ_xi.real, circ_xi.imag, color='#FF0D0D', linewidth=2, linestyle='-')
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.title(r'$\xi$-plane', fontsize=20)

plt.figure(figsize=(2*size+1, size))
plt.subplot(121)
plt.quiver(Z.real[::3,::3], Z.imag[::3,::3], w_z.real[::3,::3], -w_z.imag[::3,::3], units='inches', width=0.01, scale_units='inches', scale=7.0)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
plt.quiver(Xi.real[::3,::3], Xi.imag[::3,::3], w_xi.real[::3,::3], -w_xi.imag[::3,::3], units='inches', width=0.01, scale_units='inches', scale=7.0)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title(r'$\xi$-plane', fontsize=20)

plt.figure(figsize=(2*size+3, size))
plt.subplot(121)
contf = plt.contourf(Z.real, Z.imag, c_p_z, levels=np.linspace(-1.0, 1.0, 51), extend='both', cmap=plt.cm.jet)
cbar = plt.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title('$z$-plane', fontsize=20)

plt.subplot(122)
contf2 = plt.contourf(Xi.real, Xi.imag, c_p_xi, levels=np.linspace(-1.0, 1.0, 51), extend='both', cmap=plt.cm.jet)
cbar2 = plt.colorbar(contf2)
cbar2.set_label('$C_p$', fontsize=16)
plt.xlabel('Real', fontsize=16)
plt.ylabel('Imaginary', fontsize=16)
plt.xlim(x_start, x_end)
plt.ylim(y_start, y_end)
plt.title(r'$\xi$-plane', fontsize=20);
# Out:
# /home/bob/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:12: RuntimeWarning: divide by zero encountered in true_divide
# /home/bob/anaconda3/lib/python3.6/site-packages/numpy/ma/core.py:2761: ComplexWarning: Casting complex values to real discards the imaginary part
#   order=order, subok=True, ndmin=ndmin)

# %% [markdown]
# ### Questions
#
# What is the strength of the vortex?

# %%
gamma
# Out:
# 4.9426446603975842

# %% [markdown]
# What is the lift?

# %%
u_inf*gamma*np.cos(a_o_a)
# Out:
# 4.6445667145424823

# %% [markdown]
# Calculate the lift and drag directly. Does lift agree with K-J theorem? How much is the drag?

# %%
integrand = 1/2*u_inf**2*c_p_z[1:,0]*np.sin(theta[1:])*R
l = -np.trapz(integrand, theta[1:])
l
# Out:
# 4.6451101643918884

# %%
integrand2 = 1/2*u_inf**2*c_p_z[1:,0]*np.cos(theta[1:])*R
d = np.trapz(integrand2, theta[1:])
d
# Out:
# 1.6654924332202088

# %% [markdown]
# Where are the stagnation point indeces on the airfoil?

# %%
np.unravel_index(np.argmax(c_p_xi[:,0]), np.shape(c_p_xi[:,0]))[0]+1
# Out:
# 89

# %% [markdown]
# What is the pressure coefficient at the 111th point on the airfoil?

# %%
c_p_xi[110,0]
# Out:
# 0.49669467238347398

# %% [markdown]
# What is the velocity at the 92nd point on the airfoil?

# %%
w_xi[91,0]
# Out:
# (0.20848311620747642+0.03198838919505255j)
